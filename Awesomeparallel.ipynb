# %%
from langgraph.graph import StateGraph,START, END
from typing import TypedDict

# %%
class Batsman(TypedDict):
    runs: int
    balls: int
    fours: int
    sixes: int
    sr: float
    bpb: float
    boundary_percentage: float
    summary: str

# %%
def calculate_sr(state: Batsman) -> Batsman:
    sr = (state['runs'] / state['balls']) * 100
    return {'sr':sr}
def calculate_bpb(state: Batsman) -> Batsman:
    bpb = state['balls'] / state['runs'] if state['runs'] != 0 else 0
    return {'bpb':bpb}
def calculate_boundary_percentage(state: Batsman) -> Batsman:
    total_boundaries = state['fours'] + state['sixes']
    boundary_percentage = (total_boundaries / state['balls']) * 100 if state['balls'] != 0 else 0
    return {'boundary_percentage':boundary_percentage}

# %%
def summary(state: Batsman) -> str:
    return {'summary':f"Batsman scored {state['runs']} runs off {state['balls']} balls with a strike rate of {state['sr']:.2f}, balls per run of {state['bpb']:.2f}, and boundary percentage of {state['boundary_percentage']:.2f}%."}

# %%
graph=StateGraph(Batsman)
graph.add_node('calculate_sr',calculate_sr)
graph.add_node('calculate_bpb',calculate_bpb)
graph.add_node('calculate_boundary_percentage',calculate_boundary_percentage)
graph.add_node('summary',summary)

graph.add_edge(START,'calculate_sr')
graph.add_edge(START,'calculate_bpb')
graph.add_edge(START,'calculate_boundary_percentage')
graph.add_edge('calculate_sr','summary')
graph.add_edge('calculate_bpb','summary')
graph.add_edge('calculate_boundary_percentage','summary')
graph.add_edge('summary',END)   
workflow=graph.compile()

# %%
workflow.invoke({
    'runs': 120,
    'balls': 75,
    'fours': 10,
    'sixes': 5})
# Out:
# {'runs': 120,
#  'balls': 75,
#  'fours': 10,
#  'sixes': 5,
#  'sr': 160.0,
#  'bpb': 0.625,
#  'boundary_percentage': 20.0,
#  'summary': 'Batsman scored 120 runs off 75 balls with a strike rate of 160.00, balls per run of 0.62, and boundary percentage of 20.00%.'}

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
)

# %%
model.invoke("what is name of india's capital?")
# Out:
# AIMessage(content='The capital of India is **New Delhi**.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6e77-31b2-7dc0-a769-d7292db2bfb6-0', usage_metadata={'input_tokens': 10, 'output_tokens': 37, 'total_tokens': 47, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}})

# %%
from pydantic import BaseModel, Field

# %%
class EvaluationSchema(BaseModel):
   feedback: str = Field(..., description="Feedback on the model's response")
   score: int = Field(..., ge=1, le=10, description="Score from 1 to 10 evaluating the response quality")

# %%
structured_model=model.with_structured_output(EvaluationSchema)

# %%
x=model.invoke("Explain the theory of relativity in simple terms.").content

# %%
x
# Out:
# 'The theory of relativity, developed by Albert Einstein, fundamentally changed our understanding of space, time, gravity, and the universe. It\'s often broken down into two main parts: **Special Relativity** and **General Relativity**.\n\nLet\'s break them down in simple terms:\n\n---\n\n### The Core Idea (The "Relativity" Part)\n\nImagine you\'re on a train moving smoothly. If you drop a ball, it falls straight down. Someone standing on the ground watching the train go by would see the ball move in an arc as it falls, because they\'re also seeing the train (and you) move forward.\n\nThe *events* (dropping the ball, the ball hitting the floor) are the same, but how different observers *measure* those events (the path the ball takes) depends on their relative motion. This is the essence of "relativity" – there\'s no single, absolute viewpoint from which to measure everything.\n\n### Part 1: Special Relativity (1905)\n\nThis part deals with how space and time are relative for observers in **uniform motion** (i.e., moving at a constant speed in a straight line, without accelerating). It\'s built on two core ideas:\n\n1.  **The Principle of Relativity:** The laws of physics are the same for everyone in uniform motion, no matter their speed or direction. (Like the ball falling the same way on the train and on the ground).\n2.  **The Constant Speed of Light:** The speed of light in a vacuum is the same for *everyone*, no matter how fast they are moving or in what direction. This is the truly radical part!\n\n**What are the mind-bending consequences of the constant speed of light?**\n\nIf the speed of light is always the same for everyone, then something else has to give:\n\n*   **Time Dilation (Clocks Slow Down):** If you\'re moving very fast relative to someone else, your clock will appear to run slower to them. And their clock will appear to run slower to you! (This isn\'t just an illusion; it\'s a real physical effect). If you flew to a distant star at near light speed, you would age less than your twin who stayed on Earth.\n*   **Length Contraction (Objects Get Shorter):** Objects moving very fast appear to get shorter in the direction of their motion, as observed by someone stationary relative to them.\n*   **Mass-Energy Equivalence (E=mc²):** This famous equation comes directly from special relativity. It means that mass and energy are interchangeable – a tiny amount of mass can be converted into a huge amount of energy (like in nuclear reactions, or the sun\'s core), and vice versa. It also implies that as an object gets faster, its mass increases, making it harder and harder to accelerate, which is why nothing with mass can ever reach the speed of light.\n*   **Spacetime:** Instead of thinking of space and time as separate things, special relativity showed they are interwoven into a single, four-dimensional fabric called "spacetime." Moving through space affects your movement through time, and vice-versa.\n\n**In simple terms for Special Relativity:** Everything is relative except the speed of light. To keep the speed of light constant for all observers, space and time themselves must "stretch" and "shrink" depending on your motion.\n\n---\n\n### Part 2: General Relativity (1915)\n\nThis part expanded special relativity to include **acceleration and gravity**. It provides a completely new way of understanding gravity.\n\n*   **Gravity is Not a Force:** Instead of thinking of gravity as a mysterious force pulling objects together (like Newton did), Einstein proposed that **gravity is a curvature or warping of spacetime itself, caused by mass and energy.**\n\n**Imagine this analogy:**\n\n*   Lay a large, stretched rubber sheet flat (this is spacetime).\n*   Place a heavy bowling ball in the middle (this is a massive object like the Sun or Earth). The bowling ball creates a dip or curve in the rubber sheet.\n*   Now roll a marble across the sheet (this is a planet or a beam of light). Instead of the bowling ball "pulling" the m ...

# %%
prompt="evaluate the language quality of following essay and provide a feedback along with a score from 1 to 10:\n\n"+x
structured_model.invoke(prompt)
# Out:
# EvaluationSchema(feedback='The language quality of this essay is exceptionally clear, precise, and highly effective in explaining complex scientific concepts to a general audience. The use of simple, accessible terms and well-chosen analogies (like the train and the rubber sheet) is outstanding, making challenging ideas like time dilation and spacetime curvature remarkably easy to grasp. The essay maintains an engaging and conversational tone throughout, which significantly aids comprehension. The structure is logical with clear headings, and the flow between sections is smooth. There are no grammatical errors or awkward phrasing, demonstrating excellent command of written English. It successfully balances scientific accuracy with pedagogical clarity.', score=9)

# %%
from typing import TypedDict, Annotated, List
import operator

class UpscState(TypedDict):
    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[List[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: UpscState):
  prompt = f"""Evaluate the language quality of the following essay and provide feedback along with a score from 1 to 10:{state['essay']}"""
  output=structured_model.invoke(prompt)
  return {'language_feedback':output.feedback,'individual_scores':[output.score]}
def evaluate_analysis(state: UpscState):
  prompt = f"""Evaluate the analysis quality of the following essay and provide feedback along with a score from 1 to 10:{state['essay']}"""
  output=structured_model.invoke(prompt)
  return {'analysis_feedback':output.feedback,'individual_scores':[output.score]}
def evaluate_clarity(state: UpscState):
  prompt = f"""Evaluate the clarity of the following essay and provide feedback along with a score from 1 to 10:{state['essay']}"""
  output=structured_model.invoke(prompt)
  return {'clarity_feedback':output.feedback,'individual_scores':[output.score]}
def evaluate_overall(state: UpscState):
  prompt = f"""Evaluate the overall quality of the following essay and provide feedback along with a score from 1 to 10:{state['essay']}"""
  output=structured_model.invoke(prompt)
  avg_score=sum(state['individual_scores'])/len(state['individual_scores'])
  return {'overall_feedback':output.feedback,'avg_score':avg_score}

# %%
graph=StateGraph(UpscState)
graph.add_node('evaluate_language',evaluate_language)
graph.add_node('evaluate_analysis',evaluate_analysis)
graph.add_node('evaluate_clarity',evaluate_clarity)
graph.add_node('evaluate_overall',evaluate_overall)
graph.add_edge(START,'evaluate_language')
graph.add_edge(START,'evaluate_analysis')
graph.add_edge(START,'evaluate_clarity')
graph.add_edge('evaluate_language','evaluate_overall')
graph.add_edge('evaluate_analysis','evaluate_overall')
graph.add_edge('evaluate_clarity','evaluate_overall')
graph.add_edge('evaluate_overall',END)   
workflow=graph.compile()

# %%
workflow.invoke({
    'essay': x,
    })
# Out:
# {'essay': 'The theory of relativity, developed by Albert Einstein, fundamentally changed our understanding of space, time, gravity, and the universe. It\'s often broken down into two main parts: **Special Relativity** and **General Relativity**.\n\nLet\'s break them down in simple terms:\n\n---\n\n### The Core Idea (The "Relativity" Part)\n\nImagine you\'re on a train moving smoothly. If you drop a ball, it falls straight down. Someone standing on the ground watching the train go by would see the ball move in an arc as it falls, because they\'re also seeing the train (and you) move forward.\n\nThe *events* (dropping the ball, the ball hitting the floor) are the same, but how different observers *measure* those events (the path the ball takes) depends on their relative motion. This is the essence of "relativity" – there\'s no single, absolute viewpoint from which to measure everything.\n\n### Part 1: Special Relativity (1905)\n\nThis part deals with how space and time are relative for observers in **uniform motion** (i.e., moving at a constant speed in a straight line, without accelerating). It\'s built on two core ideas:\n\n1.  **The Principle of Relativity:** The laws of physics are the same for everyone in uniform motion, no matter their speed or direction. (Like the ball falling the same way on the train and on the ground).\n2.  **The Constant Speed of Light:** The speed of light in a vacuum is the same for *everyone*, no matter how fast they are moving or in what direction. This is the truly radical part!\n\n**What are the mind-bending consequences of the constant speed of light?**\n\nIf the speed of light is always the same for everyone, then something else has to give:\n\n*   **Time Dilation (Clocks Slow Down):** If you\'re moving very fast relative to someone else, your clock will appear to run slower to them. And their clock will appear to run slower to you! (This isn\'t just an illusion; it\'s a real physical effect). If you flew to a distant star at near light speed, you would age less than your twin who stayed on Earth.\n*   **Length Contraction (Objects Get Shorter):** Objects moving very fast appear to get shorter in the direction of their motion, as observed by someone stationary relative to them.\n*   **Mass-Energy Equivalence (E=mc²):** This famous equation comes directly from special relativity. It means that mass and energy are interchangeable – a tiny amount of mass can be converted into a huge amount of energy (like in nuclear reactions, or the sun\'s core), and vice versa. It also implies that as an object gets faster, its mass increases, making it harder and harder to accelerate, which is why nothing with mass can ever reach the speed of light.\n*   **Spacetime:** Instead of thinking of space and time as separate things, special relativity showed they are interwoven into a single, four-dimensional fabric called "spacetime." Moving through space affects your movement through time, and vice-versa.\n\n**In simple terms for Special Relativity:** Everything is relative except the speed of light. To keep the speed of light constant for all observers, space and time themselves must "stretch" and "shrink" depending on your motion.\n\n---\n\n### Part 2: General Relativity (1915)\n\nThis part expanded special relativity to include **acceleration and gravity**. It provides a completely new way of understanding gravity.\n\n*   **Gravity is Not a Force:** Instead of thinking of gravity as a mysterious force pulling objects together (like Newton did), Einstein proposed that **gravity is a curvature or warping of spacetime itself, caused by mass and energy.**\n\n**Imagine this analogy:**\n\n*   Lay a large, stretched rubber sheet flat (this is spacetime).\n*   Place a heavy bowling ball in the middle (this is a massive object like the Sun or Earth). The bowling ball creates a dip or curve in the rubber sheet.\n*   Now roll a marble across the sheet (this is a planet or a beam of light). Instead of the bowling ball "pull ...
#  'language_feedback': 'The language quality of this essay is exceptional. It masterfully simplifies complex concepts like Special and General Relativity using clear, accessible prose and highly effective analogies (e.g., the train and the rubber sheet). The structure is logical, making the flow easy to follow, and the use of headings and bullet points greatly enhances readability. The tone is engaging and informative, successfully demystifying a challenging scientific topic for a general audience. There is a strong command of language, ensuring precision without sacrificing clarity.',
#  'analysis_feedback': "This essay provides an exceptionally clear, concise, and accurate explanation of the Theory of Relativity. The breakdown into Special and General Relativity is well-structured and easy to follow. The use of analogies, such as the train and the rubber sheet, is highly effective in simplifying complex concepts. The 'In simple terms' summaries are excellent for reinforcing understanding. Furthermore, the inclusion of real-world applications like GPS truly highlights the theory's significance. This is a very well-written piece that successfully makes a challenging scientific topic accessible to a broad audience. No significant improvements are needed; it's a stellar explanation.",
#  'clarity_feedback': 'The essay provides an exceptionally clear and well-structured explanation of the theory of relativity. The use of analogies, particularly the train for special relativity and the rubber sheet for general relativity, is outstanding and makes highly complex concepts remarkably accessible. The essay is logically organized, breaking down each part into core ideas and their consequences, and uses clear, concise language. The "Why Does It Matter?" section effectively highlights the practical relevance. Overall, it\'s a masterful job of simplifying a challenging topic without sacrificing accuracy.',
#  'overall_feedback': "This essay provides an exceptionally clear, accurate, and well-structured explanation of both Special and General Relativity in simple terms. The analogies used (train, rubber sheet) are highly effective in demystifying complex concepts. The breakdown of core ideas, consequences, and real-world applications (like GPS) is excellent. The language is accessible, engaging, and maintains a perfect balance between simplicity and scientific accuracy. The 'In simple terms for...' summaries are a great touch for reinforcing understanding. This is a model example of explaining complex scientific theories to a general audience.",
#  'individual_scores': [10, 10, 9],
#  'avg_score': 9.666666666666666}
